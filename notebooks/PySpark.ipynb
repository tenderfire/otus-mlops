# %% [markdown]
# ## Пример на pyspark
#
# В качестве набора данных для примера будем использовать данные конкурса про ответы студентов на тесты
# https://www.kaggle.com/c/riiid-test-answer-prediction

# %% [markdown]
# При подключении к spark драйверу установим лимиты по памяти и по числу ядер. Также выберем номер порта для Spark UI

# %% [markdown]
# Нужно выбрать уникальное имя приложения и номер порта, чтобы не войти в коллизию с другими пользователями

# %%
# %pylab inline
import pandas as pd
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession
        .builder
        .appName("OTUS")
        .config("spark.dynamicAllocation.enabled", "true")
        .config("spark.executor.memory", "2g")
        .config("spark.driver.memory", "1g")
        .getOrCreate()
)

# %% [markdown]
# Данные будем читать из заранее сконвертированного parquet

# %%
# Читаем файл с HDFS
# Сначала попробуем прочитать как текст, чтобы увидеть структуру
riiid_df = spark.read.text("data/2022-11-04.txt")

# %% [markdown]
# ### Исследование структуры файла
# Посмотрим первые несколько строк файла, чтобы понять его формат

# %%
# Используем системную команду head для просмотра файла на HDFS
# !hdfs dfs -cat data/2022-11-04.txt | head -20
# Out:
# # tranaction_id | tx_datetime | customer_id | terminal_id | tx_amount | tx_time_seconds | tx_time_days | tx_fraud | tx_fraud_scenario
# 1832792610,2022-11-04 14:22:18,0,53,63.58,101139738,1170,0,0
# 1832792611,2022-11-04 02:12:24,0,53,92.95,101095944,1170,0,0
# 1832792612,2022-11-04 12:49:35,3,205,48.88,101134175,1170,0,0
# 1832792613,2022-11-04 02:40:01,5,383,24.69,101097601,1170,0,0
# 1832792614,2022-11-04 08:02:05,6,858,95.48,101116925,1170,0,0
# 1832792615,2022-11-04 05:45:04,8,931,60.98,101108704,1170,0,0
# 1832792616,2022-11-04 20:01:50,8,931,28.48,101160110,1170,0,0
# 1832792617,2022-11-04 15:11:42,9,450,7.89,101142702,1170,0,0
# 1832792618,2022-11-04 11:20:49,10,549,63.37,101128849,1170,0,0
# 1832792619,2022-11-04 23:11:46,10,549,78.02,101171506,1170,0,0
# 1832792620,2022-11-04 10:26:06,11,337,68.54,101125566,1170,0,0
# 1832792621,2022-11-04 14:13:55,11,337,12.04,101139235,1170,0,0
# 1832792622,2022-11-04 04:17:01,11,975,76.00,101103421,1170,0,0
# 1832792623,2022-11-04 07:39:18,11,975,12.08,101115558,1170,0,0
# 1832792624,2022-11-04 10:02:03,12,745,29.19,101124123,1170,0,0
# 1832792625,2022-11-04 08:13:21,12,745,110.49,101117601,1170,0,0
# 1832792626,2022-11-04 11:11:49,12,745,165.48,101128309,1170,0,0
# 1832792627,2022-11-04 08:14:10,13,559,69.20,101117650,1170,0,0
# 1832792628,2022-11-04 11:59:01,14,186,12.86,101131141,1170,0,0
# cat: Unable to write to output stream.

# %%
# Посмотрим первые 20 строк файла как текст
riiid_df.show(20, truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------+
# |_c0                                                                                                                                  |
# +-------------------------------------------------------------------------------------------------------------------------------------+
# |# tranaction_id | tx_datetime | customer_id | terminal_id | tx_amount | tx_time_seconds | tx_time_days | tx_fraud | tx_fraud_scenario|
# |1832792610                                                                                                                           |
# |1832792611                                                                                                                           |
# |1832792612                                                                                                                           |
# |1832792613                                                                                                                           |
# |1832792614                                                                                                                           |
# |1832792615                                                                                                                           |
# |1832792616                                                                                                                           |
# |1832792617                                                                                                                           |
# |1832792618                                                                                                                           |
# |1832792619                                                                                                                           |
# |1832792620                                                                                                                           |
# |1832792621                                                                                                                           |
# |1832792622                                                                                                                           |
# |1832792623                                                                                                                           |
# |1832792624                                                                                                                           |
# |1832792625                                                                                                                           |
# |1832792626                                                                                                                           |
# |1832792627                                                                                                                           |
# |1832792628                                                                                                                           |
# +-------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
# Подсчитаем общее количество строк
print(f"Общее количество строк: {riiid_df.count()}")
# Out:
# Общее количество строк: 46998984

# %% [markdown]
# После просмотра первых строк определим разделитель и прочитаем файл правильно

# %%
# Файл имеет заголовок с разделителем '|', но данные с разделителем ','
# Опеределяем схему
from pyspark.sql.types import StructType, StructField, LongType, StringType, DoubleType, IntegerType

# Определяем схему вручную на основе заголовка
schema = StructType([
    StructField("tranaction_id", LongType(), True),
    StructField("tx_datetime", StringType(), True),
    StructField("customer_id", IntegerType(), True),
    StructField("terminal_id", IntegerType(), True),
    StructField("tx_amount", DoubleType(), True),
    StructField("tx_time_seconds", LongType(), True),
    StructField("tx_time_days", IntegerType(), True),
    StructField("tx_fraud", IntegerType(), True),
    StructField("tx_fraud_scenario", IntegerType(), True)
])

# Читаем файл
riiid_df = (
    spark.read.csv(
        "data/2022-11-04.txt",
        sep=",",           # разделитель - запятая
        schema=schema      # используем определённую схему
    )
    .filter(col("tranaction_id").isNotNull())  # убираем строку с заголовком (она станет null)
)

# %% [markdown]
# Проверим структуру данных после правильного чтения

# %%
# Выведем схему данных
riiid_df.printSchema()
# Out:
# root
#  |-- tranaction_id: long (nullable = true)
#  |-- tx_datetime: string (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- terminal_id: integer (nullable = true)
#  |-- tx_amount: double (nullable = true)
#  |-- tx_time_seconds: long (nullable = true)
#  |-- tx_time_days: integer (nullable = true)
#  |-- tx_fraud: integer (nullable = true)
#  |-- tx_fraud_scenario: integer (nullable = true)

# %%
# Посмотрим первые записи
riiid_df.show(10, truncate=False)
# Out:
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |tranaction_id|tx_datetime        |customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |1832792610   |2022-11-04 14:22:18|0          |53         |63.58    |101139738      |1170        |0       |0                |
# |1832792611   |2022-11-04 02:12:24|0          |53         |92.95    |101095944      |1170        |0       |0                |
# |1832792612   |2022-11-04 12:49:35|3          |205        |48.88    |101134175      |1170        |0       |0                |
# |1832792613   |2022-11-04 02:40:01|5          |383        |24.69    |101097601      |1170        |0       |0                |
# |1832792614   |2022-11-04 08:02:05|6          |858        |95.48    |101116925      |1170        |0       |0                |
# |1832792615   |2022-11-04 05:45:04|8          |931        |60.98    |101108704      |1170        |0       |0                |
# |1832792616   |2022-11-04 20:01:50|8          |931        |28.48    |101160110      |1170        |0       |0                |
# |1832792617   |2022-11-04 15:11:42|9          |450        |7.89     |101142702      |1170        |0       |0                |
# |1832792618   |2022-11-04 11:20:49|10         |549        |63.37    |101128849      |1170        |0       |0                |
# |1832792619   |2022-11-04 23:11:46|10         |549        |78.02    |101171506      |1170        |0       |0                |
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# only showing top 10 rows

# %%
# Проверим количество строк и колонок
print(f"Количество строк: {riiid_df.count()}")
print(f"Количество колонок: {len(riiid_df.columns)}")
print(f"Названия колонок: {riiid_df.columns}")
# Out:
# Количество строк: 46998983
# Количество колонок: 9
# Названия колонок: ['tranaction_id', 'tx_datetime', 'customer_id', 'terminal_id', 'tx_amount', 'tx_time_seconds', 'tx_time_days', 'tx_fraud', 'tx_fraud_scenario']

# %% [markdown]
# Схема данных и первые 10 записей

# %%
riiid_df.printSchema()
# Out:
# root
#  |-- tranaction_id: long (nullable = true)
#  |-- tx_datetime: string (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- terminal_id: integer (nullable = true)
#  |-- tx_amount: double (nullable = true)
#  |-- tx_time_seconds: long (nullable = true)
#  |-- tx_time_days: integer (nullable = true)
#  |-- tx_fraud: integer (nullable = true)
#  |-- tx_fraud_scenario: integer (nullable = true)

# %%
riiid_df.show(10)
# Out:
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |   1832792610|2022-11-04 14:22:18|          0|         53|    63.58|      101139738|        1170|       0|                0|
# |   1832792611|2022-11-04 02:12:24|          0|         53|    92.95|      101095944|        1170|       0|                0|
# |   1832792612|2022-11-04 12:49:35|          3|        205|    48.88|      101134175|        1170|       0|                0|
# |   1832792613|2022-11-04 02:40:01|          5|        383|    24.69|      101097601|        1170|       0|                0|
# |   1832792614|2022-11-04 08:02:05|          6|        858|    95.48|      101116925|        1170|       0|                0|
# |   1832792615|2022-11-04 05:45:04|          8|        931|    60.98|      101108704|        1170|       0|                0|
# |   1832792616|2022-11-04 20:01:50|          8|        931|    28.48|      101160110|        1170|       0|                0|
# |   1832792617|2022-11-04 15:11:42|          9|        450|     7.89|      101142702|        1170|       0|                0|
# |   1832792618|2022-11-04 11:20:49|         10|        549|    63.37|      101128849|        1170|       0|                0|
# |   1832792619|2022-11-04 23:11:46|         10|        549|    78.02|      101171506|        1170|       0|                0|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# only showing top 10 rows

# %%
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)  # to pretty print pyspark.DataFrame in jupyter
riiid_df
# Out:
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |   1832792610|2022-11-04 14:22:18|          0|         53|    63.58|      101139738|        1170|       0|                0|
# |   1832792611|2022-11-04 02:12:24|          0|         53|    92.95|      101095944|        1170|       0|                0|
# |   1832792612|2022-11-04 12:49:35|          3|        205|    48.88|      101134175|        1170|       0|                0|
# |   1832792613|2022-11-04 02:40:01|          5|        383|    24.69|      101097601|        1170|       0|                0|
# |   1832792614|2022-11-04 08:02:05|          6|        858|    95.48|      101116925|        1170|       0|                0|
# |   1832792615|2022-11-04 05:45:04|          8|        931|    60.98|      101108704|        1170|       0|                0|
# |   1832792616|2022-11-04 20:01:50|          8|        931|    28.48|      101160110|        1170|       0|                0|
# |   1832792617|2022-11-04 15:11:42|          9|        450|     7.89|      101142702|        1170|       0|                0|
# |   1832792618|2022-11-04 11:20:49|         10|        549|    63.37|      101128849|        1170|       0|                0|
# |   1832792619|2022-11-04 23:11:46|         10|        549|    78.02|      101171506|        1170|       0|                0|
# |   1832792620|2022-11-04 10:26:06|         11|        337|    68.54|      101125566|        1170|       0|                0|
# |   1832792621|2022-11-04 14:13:55|         11|        337|    12.04|      101139235|        1170|       0|                0|
# |   1832792622|2022-11-04 04:17:01|         11|        975|     76.0|      101103421|        1170|       0|                0|
# |   1832792623|2022-11-04 07:39:18|         11|        975|    12.08|      101115558|        1170|       0|                0|
# |   1832792624|2022-11-04 10:02:03|         12|        745|    29.19|      101124123|        1170|       0|                0|
# |   1832792625|2022-11-04 08:13:21|         12|        745|   110.49|      101117601|        1170|       0|                0|
# |   1832792626|2022-11-04 11:11:49|         12|        745|   165.48|      101128309|        1170|       0|                0|
# |   1832792627|2022-11-04 08:14:10|         13|        559|     69.2|      101117650|        1170|       0|                0|
# |   1832792628|2022-11-04 11:59:01|         14|        186|    12.86|      101131141|        1170|       0|                0|
# |   1832792629|2022-11-04 09:33:56|         14|        460|     3.97|      101122436|        1170|       0|                0|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ### Сохраним в паркет

# %%
# Проверим, что null-строки убраны
print(f"Количество записей: {riiid_df.count()}")
riiid_df.show(5)

# Сохраним в parquet
(
    riiid_df
        .write
        .mode("overwrite")
        .parquet("data/2022-11-04.parquet")
)
# Out:
# Количество записей: 46998983
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |   1832792610|2022-11-04 14:22:18|          0|         53|    63.58|      101139738|        1170|       0|                0|
# |   1832792611|2022-11-04 02:12:24|          0|         53|    92.95|      101095944|        1170|       0|                0|
# |   1832792612|2022-11-04 12:49:35|          3|        205|    48.88|      101134175|        1170|       0|                0|
# |   1832792613|2022-11-04 02:40:01|          5|        383|    24.69|      101097601|        1170|       0|                0|
# |   1832792614|2022-11-04 08:02:05|          6|        858|    95.48|      101116925|        1170|       0|                0|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# only showing top 5 rows
#
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |   1832792610|2022-11-04 14:22:18|          0|         53|    63.58|      101139738|        1170|       0|                0|
# |   1832792611|2022-11-04 02:12:24|          0|         53|    92.95|      101095944|        1170|       0|                0|
# |   1832792612|2022-11-04 12:49:35|          3|        205|    48.88|      101134175|        1170|       0|                0|
# |   1832792613|2022-11-04 02:40:01|          5|        383|    24.69|      101097601|        1170|       0|                0|
# |   1832792614|2022-11-04 08:02:05|          6|        858|    95.48|      101116925|        1170|       0|                0|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# only showing top 5 rows

# %%
# Посмотрим содержимое директории parquet
# !hdfs dfs -ls data/2022-11-04.parquet

print("\n" + "="*50)
print("Размер файлов внутри parquet директории:")
print("="*50)
# !hdfs dfs -du -h data/2022-11-04.parquet
# Out:
# Found 25 items
# -rw-r--r--   1 ubuntu hadoop          0 2025-10-28 14:57 data/2022-11-04.parquet/_SUCCESS
# -rw-r--r--   1 ubuntu hadoop   38373646 2025-10-28 14:57 data/2022-11-04.parquet/part-00000-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   39334709 2025-10-28 14:57 data/2022-11-04.parquet/part-00001-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   40269792 2025-10-28 14:57 data/2022-11-04.parquet/part-00002-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   41225825 2025-10-28 14:57 data/2022-11-04.parquet/part-00003-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   38764936 2025-10-28 14:57 data/2022-11-04.parquet/part-00004-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   39660129 2025-10-28 14:57 data/2022-11-04.parquet/part-00005-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   40655815 2025-10-28 14:57 data/2022-11-04.parquet/part-00006-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   38329426 2025-10-28 14:57 data/2022-11-04.parquet/part-00007-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   39135806 2025-10-28 14:57 data/2022-11-04.parquet/part-00008-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   40158832 2025-10-28 14:57 data/2022-11-04.parquet/part-00009-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   41072054 2025-10-28 14:57 data/2022-11-04.parquet/part-00010-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   38575793 2025-10-28 14:57 data/2022-11-04.parquet/part-00011-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   39545510 2025-10-28 14:57 data/2022-11-04.parquet/part-00012-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   40516476 2025-10-28 14:57 data/2022-11-04.parquet/part-00013-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   38279373 2025-10-28 14:57 data/2022-11-04.parquet/part-00014-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   38986975 2025-10-28 14:57 data/2022-11-04.parquet/part-00015-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   39962427 2025-10-28 14:57 data/2022-11-04.parquet/part-00016-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   40937546 2025-10-28 14:57 data/2022-11-04.parquet/part-00017-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   38423441 2025-10-28 14:57 data/2022-11-04.parquet/part-00018-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   39436265 2025-10-28 14:57 data/2022-11-04.parquet/part-00019-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   40332165 2025-10-28 14:57 data/2022-11-04.parquet/part-00020-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   38180140 2025-10-28 14:57 data/2022-11-04.parquet/part-00021-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   38776957 2025-10-28 14:57 data/2022-11-04.parquet/part-00022-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# -rw-r--r--   1 ubuntu hadoop   13926523 2025-10-28 14:57 data/2022-11-04.parquet/part-00023-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
#
# ==================================================
# Размер файлов внутри parquet директории:
# ==================================================
#
# ==================================================
# Размер файлов внутри parquet директории:
# ==================================================
# 0       0       data/2022-11-04.parquet/_SUCCESS
# 36.6 M  36.6 M  data/2022-11-04.parquet/part-00000-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.5 M  37.5 M  data/2022-11-04.parquet/part-00001-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.4 M  38.4 M  data/2022-11-04.parquet/part-00002-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 39.3 M  39.3 M  data/2022-11-04.parquet/part-00003-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.0 M  37.0 M  data/2022-11-04.parquet/part-00004-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.8 M  37.8 M  data/2022-11-04.parquet/part-00005-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.8 M  38.8 M  data/2022-11-04.parquet/part-00006-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.6 M  36.6 M  data/2022-11-04.parquet/part-00007-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.3 M  37.3 M  data/2022-11-04.parquet/part-00008-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.3 M  38.3 M  data/2022-11-04.parquet/part-00009-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 39.2 M  39.2 M  data/2022-11-04.parquet/part-00010-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.8 M  36.8 M  data/2022-11-04.parquet/part-00011-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.7 M  37.7 M  data/2022-11-04.parquet/part-00012-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.6 M  38.6 M  data/2022-11-04.parquet/part-00013-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.5 M  36.5 M  data/2022-11-04.parquet/part-00014-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.2 M  37.2 M  data/2022-11-04.parquet/part-00015-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.1 M  38.1 M  data/2022-11-04.parquet/part-00016-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 39.0 M  39.0 M  data/2022-11-04.parquet/part-00017-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.6 M  36.6 M  data/2022-11-04.parquet/part-00018-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.6 M  37.6 M  data/2022-11-04.parquet/part-00019-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.5 M  38.5 M  data/2022-11-04.parquet/part-00020-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.4 M  36.4 M  data/2022-11-04.parquet/part-00021-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.0 M  37.0 M  data/2022-11-04.parquet/part-00022-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 13.3 M  13.3 M  data/2022-11-04.parquet/part-00023-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 0       0       data/2022-11-04.parquet/_SUCCESS
# 36.6 M  36.6 M  data/2022-11-04.parquet/part-00000-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.5 M  37.5 M  data/2022-11-04.parquet/part-00001-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.4 M  38.4 M  data/2022-11-04.parquet/part-00002-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 39.3 M  39.3 M  data/2022-11-04.parquet/part-00003-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.0 M  37.0 M  data/2022-11-04.parquet/part-00004-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.8 M  37.8 M  data/2022-11-04.parquet/part-00005-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.8 M  38.8 M  data/2022-11-04.parquet/part-00006-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.6 M  36.6 M  data/2022-11-04.parquet/part-00007-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.3 M  37.3 M  data/2022-11-04.parquet/part-00008-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.3 M  38.3 M  data/2022-11-04.parquet/part-00009-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 39.2 M  39.2 M  data/2022-11-04.parquet/part-00010-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.8 M  36.8 M  data/2022-11-04.parquet/part-00011-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.7 M  37.7 M  data/2022-11-04.parquet/part-00012-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.6 M  38.6 M  data/2022-11-04.parquet/part-00013-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.5 M  36.5 M  data/2022-11-04.parquet/part-00014-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.2 M  37.2 M  data/2022-11-04.parquet/part-00015-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.1 M  38.1 M  data/2022-11-04.parquet/part-00016-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 39.0 M  39.0 M  data/2022-11-04.parquet/part-00017-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.6 M  36.6 M  data/2022-11-04.parquet/part-00018-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.6 M  37.6 M  data/2022-11-04.parquet/part-00019-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 38.5 M  38.5 M  data/2022-11-04.parquet/part-00020-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 36.4 M  36.4 M  data/2022-11-04.parquet/part-00021-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 37.0 M  37.0 M  data/2022-11-04.parquet/part-00022-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet
# 13.3 M  13.3 M  data/2022-11-04.parquet/part-00023-1b3fb4df-c0b6-4aba-a614-6a24de12e602-c000.snappy.parquet

# %% [markdown]
# Теперь прочитаем parquet и проверим, что данные сохранились

# %%
# Читаем parquet обратно
df_from_parquet = spark.read.parquet("data/2022-11-04.parquet")

print(f"Количество записей в parquet: {df_from_parquet.count()}")
print(f"Схема данных:")
df_from_parquet.printSchema()
print("\nПервые 5 записей:")
df_from_parquet.show(5)
# Out:
# Количество записей в parquet: 46998983
# Схема данных:
# root
#  |-- tranaction_id: long (nullable = true)
#  |-- tx_datetime: string (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- terminal_id: integer (nullable = true)
#  |-- tx_amount: double (nullable = true)
#  |-- tx_time_seconds: long (nullable = true)
#  |-- tx_time_days: integer (nullable = true)
#  |-- tx_fraud: integer (nullable = true)
#  |-- tx_fraud_scenario: integer (nullable = true)
#
#
# Первые 5 записей:
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |   1838826044|2022-11-07 15:08:53|     850577|        324|    65.72|      101401733|        1173|       0|                0|
# |   1838826045|2022-11-07 15:09:45|     850579|        734|    83.88|      101401785|        1173|       0|                0|
# |   1838826046|2022-11-07 12:29:14|     850579|        533|    87.64|      101392154|        1173|       0|                0|
# |   1838826047|2022-11-07 06:50:02|     850580|        826|     3.81|      101371802|        1173|       0|                0|
# |   1838826048|2022-11-07 11:08:58|     850581|        115|    50.42|      101387338|        1173|       1|                2|
# +-------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# only showing top 5 rows

# %% [markdown]
# Замерим время выполнения простых запросов с группировками

# %%
from pyspark.sql import functions as f
from pyspark.sql.functions import col

# %%
# %%time
(
riiid_df
    .select('content_id', 'answered_correctly')
    .groupBy('content_id')
    .mean('answered_correctly')
    .show()
)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <timed eval> in <module>
#
# /usr/lib/spark/python/pyspark/sql/dataframe.py in select(self, *cols)
#    1419         [Row(name=u'Alice', age=12), Row(name=u'Bob', age=15)]
#    1420         """
# -> 1421         jdf = self._jdf.select(self._jcols(*cols))
#    1422         return DataFrame(jdf, self.sql_ctx)
#    1423
#
# /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /usr/lib/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     132                 # Hide where the exception came from that shows a non-Pythonic
#     133                 # JVM exception message.
# --> 134                 raise_from(converted)
#     135             else:
#     136                 raise
#
# /usr/lib/spark/python/pyspark/sql/utils.py in raise_from(e)
#
# AnalysisException: cannot resolve '`content_id`' given input columns: [customer_id, terminal_id, tranaction_id, tx_amount, tx_datetime, tx_fraud, tx_fraud_scenario, tx_time_days, tx_time_seconds];;
# 'Project ['content_id, 'answered_correctly]
# +- Relation[tranaction_id#344L,tx_datetime#345,customer_id#346,terminal_id#347,tx_amount#348,tx_time_seconds#349L,tx_time_days#350,tx_fraud#351,tx_fraud_scenario#352] csv

# %%
# %%time
(
riiid_df
    .select('user_id', 'answered_correctly')
    .where(col('answered_correctly') != -1)
    .groupby('user_id')
    .mean('answered_correctly')
    .show()
)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <timed eval> in <module>
#
# /usr/lib/spark/python/pyspark/sql/dataframe.py in select(self, *cols)
#    1419         [Row(name=u'Alice', age=12), Row(name=u'Bob', age=15)]
#    1420         """
# -> 1421         jdf = self._jdf.select(self._jcols(*cols))
#    1422         return DataFrame(jdf, self.sql_ctx)
#    1423
#
# /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /usr/lib/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     132                 # Hide where the exception came from that shows a non-Pythonic
#     133                 # JVM exception message.
# --> 134                 raise_from(converted)
#     135             else:
#     136                 raise
#
# /usr/lib/spark/python/pyspark/sql/utils.py in raise_from(e)
#
# AnalysisException: cannot resolve '`user_id`' given input columns: [customer_id, terminal_id, tranaction_id, tx_amount, tx_datetime, tx_fraud, tx_fraud_scenario, tx_time_days, tx_time_seconds];;
# 'Project ['user_id, 'answered_correctly]
# +- Relation[tranaction_id#344L,tx_datetime#345,customer_id#346,terminal_id#347,tx_amount#348,tx_time_seconds#349L,tx_time_days#350,tx_fraud#351,tx_fraud_scenario#352] csv

# %% [markdown]
# ## Упражнение 1
# Выведите top 10 студентов с наилучшими результатами.
# Обратите внимание, что поле answered_correctly равно -1, если это была лекция, а не тест. Такие записи нужно исключить.

# %% [markdown]
# ## Упражнение 2
# Выведите top 10 задач с наихудшими результатами

# %% [markdown]
# ## pyspark user defined functions (UDF)
#
# Как и для других языков, поддерживаемых Spark, для python есть возможность использовать UDF. При этом возникают дополнительные накладные расходы по сравнению с Java и Scala на маршалинг данных.

# %%
from pyspark.sql.types import LongType

def to_months(ms):
    return ms // 31536000000 // 12 #1 year = 31536000000 ms

to_months_udf = f.udf(to_months, LongType())

# %% [markdown]
# Замерим время выполнения без UDF

# %%
# %%time
(
    riiid_df
        .select("content_id", "timestamp")
        .groupby("content_id")
        .mean("timestamp")
        .show()
)

# %% [markdown]
# Применим простой UDF к похожему запросу

# %%
# %%time
(
    riiid_df
        .select("content_id", to_days_udf("timestamp").alias("months"))
        .groupBy("content_id")
        .mean("months")
        .show()
)

# %% [markdown]
# Перепишем логику, которая была в UDF

# %%
# %%time
(
 riiid_df
    .select("content_id", (col("timestamp") / 31536000000 / 12).alias("months"))
    .groupby("content_id")
    .mean("months")
    .show()
)

# %% [markdown]
# ## Упражнение 4
# Постройте гистограмму по числу месяцев до первого взаимодействия студента с заданием

# %% [markdown]
# ## Обогащение данных

# %% [markdown]
# Таблица с вопросами лежит в отдельном файле questions.csv.

# %%
questions = spark.read.csv("riiid/questions.csv", header=True, inferSchema=True)

# %%
questions.count()

# %%
questions.printSchema()

# %% [markdown]
# Объединим ее с ответами при условии, что эта запись ссылкается на вопрос если content_type_id и content_id - идентификатор вопроса.

# %%
df = (
    riiid_df.
        where(f.col("content_type_id") == 0).
        join(questions, riiid_df.content_id == questions.question_id, 'left')
)

# %%
df

# %% [markdown]
# Проверим, что вероястность правильного ответа не зависит от его номера.

# %%
# %%time
(
df
    .select('correct_answer', 'answered_correctly')
    .groupby('correct_answer')
    .mean('answered_correctly')
    .show()
)

# %% [markdown]
# ## Упражнение 5
#
# В файле "riiid/lectures.csv" хранится информация об лекциях. Объедините эту таблицу с основным набором данных при условии, что content_type_id == 1.
